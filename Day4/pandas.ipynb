# %%
import pandas as pd

# %%
df = pd.read_csv('../resources/results.csv')

# %%
df.tail()

# %%
df.duplicated()

# %%
df.head(5)

# %%
df.to_string()

# %%
pd.__version__

# %%
a = [1,2,7]
var = pd.Series(a)
var

# %%
var[1]

# %%
myVar = pd.Series(a, index = ["x", "y", "z"])
myVar

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data)

# %%
df

# %%
print(df.loc[0])

# %%
df.loc[[1,2]]

# %%
df = pd.DataFrame(data, index= ["day 1", "day 2", "day 3"])

# %%
df.loc["day 2"]

# %%
df

# %%
# check your system's maximum rows returned
pd.options.display.max_rows
# we can set it our convinence, like 999 etc. but anymore would not be goo

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

json_data = pd.DataFrame(data)
json_data

# %%
df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
df.info()

# %%
df.dropna() # removes empty (NaN) values, returns a New DataFrame and not change the original one

df.dropna(inplace = True)  # Changes the Original DataFrame entirely.

# %%
df.fillna({"team" : "Jean Montariol"})

#df.fillna({"place" : 20.0}, inplace = True)
df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
mean = df["place"].mean()
# df.fillna({"place": mean}, inplace=True)
df
median = df["place"].median()
mode = df["place"].mode()[0]
df.fillna({"place": mode}, inplace=True)
df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
data = pd.read_csv("../resources/exercise_data.csv")

# %%
student_data = [[1, 15],[2, 11],[3, 11],[4, 20]]

student_data[0(1)]
# Out:
# <>:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\ichotu\AppData\Local\Temp\ipykernel_24440\888718304.py:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   student_data[0(1)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 3
#       1 student_data = [[1, 15],[2, 11],[3, 11],[4, 20]]
# ----> 3 student_data[0(1)]
#
# TypeError: 'int' object is not callable
